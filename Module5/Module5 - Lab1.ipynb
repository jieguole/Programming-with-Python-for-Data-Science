# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module5- Lab1

# %% [markdown]
# Start by importing whatever you need to import in order to make this lab work:

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot') # Look Pretty

# %% [markdown]
# ### How to Get The Dataset

# %% [markdown]
# 1. Open up the City of Chicago's [Open Data | Crimes](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2) page.
# 1. In the `Primary Type` column, click on the `Menu` button next to the info button, and select `Filter This Column`. It might take a second for the filter option to show up, since it has to load the entire list first.
# 1. Scroll down to `GAMBLING`
# 1. Click the light blue `Export` button next to the `Filter` button, and select `Download As CSV`

# %% [markdown]
# Now that you have th dataset stored as a CSV, load it up being careful to double check headers, as per usual:

# %%
df = pd.read_csv('Datasets/Crimes_-_2001_to_present.csv')
len(df)
# Out:
# 14233

# %% [markdown]
# Get rid of any _rows_ that have nans in them:

# %%
df.dropna(axis = 0, how = 'any', inplace = True)
df
# Out:
#              ID Case Number                    Date                    Block  \
# 0      10002677    HY191890  03/20/2015 01:13:00 PM          020XX W 70TH ST
# 1      10003802    HY193541  03/21/2015 06:45:00 PM        042XX W MONROE ST
# 2      10003937    HY193663  03/21/2015 07:55:00 PM     032XX W LAWRENCE AVE
# 3      10004429    HY194332  03/22/2015 01:57:00 PM     019XX S ST LOUIS AVE
# 4      10005837    HY195964  03/23/2015 08:40:00 PM        039XX W CERMAK RD
# 5      10011726    HY200956  03/27/2015 09:10:00 AM       032XX N HARLEM AVE
# 6      10012328    HY201988  03/28/2015 06:45:00 PM  005XX N SPRINGFIELD AVE
# 7      10014339    HY203868  03/30/2015 02:19:00 PM     038XX W ROOSEVELT RD
# 8      10016050    HY205430  03/31/2015 07:05:00 PM    060XX S PRINCETON AVE
# 9      10017499    HY206880  04/01/2015 08:00:00 PM       048XX W GLADYS AVE
# 10     10017527    HY206917  04/01/2015 08:26:00 PM   065XX S MARSHFIELD AVE
# 11     10019991    HY209099  04/03/2015 02:40:00 PM          007XX W 54TH PL
# 12     10021717    HY211521  04/05/2015 06:15:00 PM        043XX W WILCOX ST
# 13     10021787    HY211542  04/05/2015 06:10:00 PM     080XX S ELIZABETH ST
# 14     10021905    HY211720  04/05/2015 09:12:00 PM   072XX S SOUTH SHORE DR
# 15     10022799    HY212450  04/06/2015 03:15:00 PM       051XX W MADISON ST
# 16     10022987    HY212632  04/06/2015 05:19:00 PM      057XX S CALUMET AVE
# 17     10023151    HY212920  04/06/2015 08:06:00 PM         052XX S GREEN ST
# 18     10025150    HY214606  04/08/2015 02:18:00 PM           067XX S MAY ST
# 19     10026553    HY215974  04/09/2015 05:15:00 PM        065XX S PEORIA ST
# 20     10026845    HY216352  04/09/2015 10:51:00 PM          005XX W 85TH ST
# 21     10027287    HY216642  04/10/2015 10:35:00 AM         050XX W ADAMS ST
# 22     10027404    HY216736  04/10/2015 11:20:00 AM     033XX W ROOSEVELT RD
# 23     10029260    HY219186  04/12/2015 01:00:00 PM       071XX S RACINE AVE
# 24     10029300    HY219250  04/12/2015 01:31:00 PM    012XX S FAIRFIELD AVE
#
#        IUCR Primary Type            Description  \
# 0      1661     GAMBLING              GAME/DICE
# 1      1661     GAMBLING              GAME/DICE
# 2      1670     GAMBLING  GAME/AMUSEMENT DEVICE
# 3      1661     GAMBLING              GAME/DICE
# 4      1661     GAMBLING              GAME/DICE
# 5      1670     GAMBLING  GAME/AMUSEMENT DEVICE
# 6      1661     GAMBLING              GAME/DICE
# 7      1661     GAMBLING              GAME/DICE
# 8      1661     GAMBLING              GAME/DICE
# 9      1661     GAMBLING              GAME/DICE
# 10     1661     GAMBLING              GAME/DICE
# 11     1661     GAMBLING              GAME/DICE
# 12     1661     GAMBLING              GAME/DICE
# 13     1661     GAMBLING              GAME/DICE
# 14     1661     GAMBLING              GAME/DICE
# 15     1661     GAMBLING              GAME/DICE
# 16     1661     GAMBLING              GAME/DICE
# 17     1661     GAMBLING              GAME/DICE
# 18     1661     GAMBLING              GAME/DICE
# 19     1661     GAMBLING              GAME/DICE
# 20     1661     GAMBLING              GAME/DICE
# 21     1661     GAMBLING              GAME/DICE
# 22     1661     GAMBLING              GAME/DICE
# 23     1661     GAMBLING              GAME/DICE
# 24     1661     GAMBLING              GAME/DICE
# 25     1661     GAMBLING              GAME/DICE
# 26     1661     GAMBLING              GAME/DICE
# 27     1661     GAMBLING              GAME/DICE
# 28     1661     GAMBLING              GAME/DICE
# 29     1661     GAMBLING              GAME/DICE
# ...     ...          ...                    ...
# 14203  1661     GAMBLING              GAME/DICE
# 14204  1661     GAMBLING              GAME/DICE
# 14205  1651     GAMBLING             GAME/CARDS
# 14206  1661     GAMBLING              GAME/DICE
# 14207  1670     GAMBLING  GAME/AMUSEMENT DEVICE
# 14208  1661     GAMBLING              GAME/DICE
# 14209  1661     GAMBLING              GAME/DICE
# 14210  1680     GAMBLING                  OTHER
# 14211  1661     GAMBLING              GAME/DICE
# 14212  1661     GAMBLING              GAME/DICE
# 14213  1661     GAMBLING              GAME/DICE
# 14214  1661     GAMBLING              GAME/DICE
# 14215  1661     GAMBLING              GAME/DICE
# 14216  1626     GAMBLING    ILLEGAL ILL LOTTERY
# 14217  1661     GAMBLING              GAME/DICE
# 14218  1661     GAMBLING              GAME/DICE
# 14219  1661     GAMBLING              GAME/DICE
# 14220  1661     GAMBLING              GAME/DICE
# 14221  1661     GAMBLING              GAME/DICE
# 14222  1661     GAMBLING              GAME/DICE
# 14223  1680     GAMBLING                  OTHER
# 14224  1661     GAMBLING              GAME/DICE
# 14225  1661     GAMBLING              GAME/DICE
# 14226  1661     GAMBLING              GAME/DICE
# 14227  1661     GAMBLING              GAME/DICE
# 14228  1661     GAMBLING              GAME/DICE
# 14229  1661     GAMBLING              GAME/DICE
# 14230  1661     GAMBLING              GAME/DICE
# 14231  1680     GAMBLING                  OTHER
# 14232  1661     GAMBLING              GAME/DICE
#
#                  Location Description Arrest Domestic  \
# 0                              STREET   True    False
# 1                            SIDEWALK   True    False
# 2                  SMALL RETAIL STORE   True    False
# 3                            SIDEWALK   True    False
# 4      PARKING LOT/GARAGE(NON.RESID.)   True    False
# 5                               OTHER   True    False
# 6                            SIDEWALK   True    False
# 7                            SIDEWALK   True    False
# 8                               ALLEY   True    False
# 9                              STREET   True    False
# 10                              ALLEY   True    False
# 11                           SIDEWALK   True    False
# 12                           SIDEWALK   True    False
# 13                              ALLEY   True    False
# 14            RESIDENCE PORCH/HALLWAY   True    False
# 15                        GAS STATION   True    False
# 16                          RESIDENCE   True    False
# 17                           SIDEWALK   True    False
# 18                           SIDEWALK   True    False
# 19                           SIDEWALK   True    False
# 20                          APARTMENT   True    False
# 21                           SIDEWALK   True    False
# 22     PARKING LOT/GARAGE(NON.RESID.)   True    False
# 23     PARKING LOT/GARAGE(NON.RESID.)   True    False
# 24                           SIDEWALK   True    False
# 25                           SIDEWALK   True    False
# 26                           SIDEWALK   True    False
# 27                           SIDEWALK   True    False
# 28                              OTHER   True    False
# 29                             STREET   True    False
# ...                               ...    ...      ...
# 14203                        SIDEWALK   True    False
# 14204                        SIDEWALK   True    False
# 14205                           OTHER   True    False
# 14206         RESIDENCE PORCH/HALLWAY   True    False
# 14207                      RESTAURANT   True    False
# 14208         SCHOOL, PUBLIC, GROUNDS   True    False
# 14209                        SIDEWALK   True    False
# 14210                        SIDEWALK   True    False
# 14211                        SIDEWALK   True    False
# 14212                          STREET   True    False
# 14213                          STREET   True    False
# 14214                        SIDEWALK   True    False
# 14215         RESIDENCE PORCH/HALLWAY   True    False
# 14216                          STREET   True    False
# 14217                        SIDEWALK   True    False
# 14218                   PARK PROPERTY   True    False
# 14219                        SIDEWALK   True    False
# 14220                        SIDEWALK   True    False
# 14221                        SIDEWALK   True    False
# 14222                           OTHER   True    False
# 14223                        SIDEWALK   True    False
# 14224                        SIDEWALK   True    False
# 14225                        SIDEWALK   True    False
# 14226                        SIDEWALK   True    False
# 14227                        SIDEWALK   True    False
# 14228                        SIDEWALK   True    False
# 14229                        SIDEWALK   True    False
# 14230                        SIDEWALK   True    False
# 14231                        SIDEWALK   True    False
# 14232                        SIDEWALK   True    False
#
#                    ...                Ward  Community Area  FBI Code  \
# 0                  ...                17.0            67.0        19
# 1                  ...                28.0            26.0        19
# 2                  ...                39.0            14.0        19
# 3                  ...                24.0            29.0        19
# 4                  ...                24.0            29.0        19
# 5                  ...                36.0            17.0        19
# 6                  ...                27.0            23.0        19
# 7                  ...                24.0            29.0        19
# 8                  ...                20.0            68.0        19
# 9                  ...                24.0            25.0        19
# 10                 ...                15.0            67.0        19
# 11                 ...                 3.0            61.0        19
# 12                 ...                28.0            26.0        19
# 13                 ...                21.0            71.0        19
# 14                 ...                 7.0            43.0        19
# 15                 ...                28.0            25.0        19
# 16                 ...                20.0            40.0        19
# 17                 ...                 3.0            61.0        19
# 18                 ...                17.0            68.0        19
# 19                 ...                17.0            68.0        19
# 20                 ...                21.0            71.0        19
# 21                 ...                28.0            25.0        19
# 22                 ...                24.0            29.0        19
# 23                 ...                17.0            68.0        19
# 24                 ...                28.0            29.0        19
# 14229 -87.695806   (41.778160655, -87.69580613)
# 14230 -87.729873  (41.859797566, -87.729873421)
# 14231 -87.768768  (41.898450542, -87.768768254)
# 14232 -87.745876  (41.891379058, -87.745875882)
#
# [13020 rows x 22 columns]

# %% [markdown]
# Display the `dtypes` of your dset:

# %%
df.dtypes
# Out:
# ID                        int64
# Case Number              object
# Date                     object
# Block                    object
# IUCR                      int64
# Primary Type             object
# Description              object
# Location Description     object
# Arrest                     bool
# Domestic                   bool
# Beat                      int64
# District                  int64
# Ward                    float64
# Community Area          float64
# FBI Code                  int64
# X Coordinate            float64
# Y Coordinate            float64
# Year                      int64
# Updated On               object
# Latitude                float64
# Longitude               float64
# Location                 object
# dtype: object

# %% [markdown]
# Coerce the `Date` feature (which is currently a string object) into real date, and confirm by displaying the `dtypes` again. This might be a slow executing process...

# %%
df.Date = pd.to_datetime(df.Date)
df.dtypes
# Out:
# ID                               int64
# Case Number                     object
# Date                    datetime64[ns]
# Block                           object
# IUCR                             int64
# Primary Type                    object
# Description                     object
# Location Description            object
# Arrest                            bool
# Domestic                          bool
# Beat                             int64
# District                         int64
# Ward                           float64
# Community Area                 float64
# FBI Code                         int64
# X Coordinate                   float64
# Y Coordinate                   float64
# Year                             int64
# Updated On                      object
# Latitude                       float64
# Longitude                      float64
# Location                        object
# dtype: object

# %%
def doKMeans(df):
    # Let's plot your data with a '.' marker, a 0.3 alpha at the Longitude,
    # and Latitude locations in your dataset. Longitude = x, Latitude = y
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.scatter(df.Longitude, df.Latitude, marker='.', alpha=0.3, s=30)

    
    # TODO: Filter `df` using indexing so it only contains Longitude and Latitude,
    # since the remaining columns aren't really applicable for this lab:
    
    df = pd.concat([df.Longitude, df.Latitude], axis = 1)


    # TODO: Use K-Means to try and find seven cluster centers in this df.
    # Be sure to name your kmeans model `model` so that the printing works.
    
    model= KMeans(n_clusters = 7, init = 'random', n_init = 60, max_iter = 360, random_state = 43)
    labels = model.fit_predict(df)


    # Now we can print and plot the centroids:
    centroids = model.cluster_centers_
    print(centroids)
    ax.scatter(centroids[:,0], centroids[:,1], marker='x', c='green', alpha=0.5, linewidths=3, s=169)
    plt.show()
    return 'done'

# %%
# Print & Plot your data
doKMeans(df)
# Out:
# [[-87.58249315  41.75253717]
#  [-87.61948454  41.80344041]
#  [-87.63108338  41.69664745]
#  [-87.70962149  41.87811376]
#  [-87.68543715  41.98128232]
#  [-87.75697475  41.89333057]
#  [-87.66470727  41.77273081]]
# 'done'

# %% [markdown]
# Filter out the data so that it only contains samples that have a `Date > '2011-01-01'`, using indexing. Then, in a new figure, plot the crime incidents, as well as a new K-Means run's centroids.

# %%
df2 = df[df.Date > '2011-01-01']

# %%
# Print & Plot your data
doKMeans(df2)
# Out:
# [[-87.71063853  41.87539857]
#  [-87.68715349  41.98350221]
#  [-87.61923368  41.79175767]
#  [-87.63498384  41.70559452]
#  [-87.66500903  41.77569441]
#  [-87.57999513  41.75033989]
#  [-87.75484509  41.8900059 ]]
# 'done'
